# %% [markdown]
# Tutorial Author:Mohammadreza Tavasoli Naeini Advisor:Hanrui Wang

# %% [markdown]
# This tutorial shows; how to use the TrochQuantum library in building a quantum transformer.
# This notebook is adapted, excerpted from https://github.com/rdisipio/qlstm, written by Riccardo Di Sipio.
# In this notebook, we use the TorchQuantum library instead of the Pennylane library to build a quantum machine learning model.

# %% [markdown]
# ## Build and train a Quantum LSTM.

# %% [markdown]
# ## Installation

# %%
# !git clone https://github.com/mit-han-lab/torchquantum.git
# Out:
# fatal: destination path 'torchquantum' already exists and is not an empty directory.

# %%
# %cd torchquantum
# Out:
# /Users/mohammad/qlstm/torchquantum

# %%
# !pip install --editable .
# Out:
# Obtaining file:///Users/mohammad/qlstm/torchquantum
# Requirement already satisfied: numpy>=1.19.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (1.20.1)
# Requirement already satisfied: torchvision>=0.9.0.dev20210130 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (0.9.1)
# Requirement already satisfied: tqdm>=4.56.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (4.60.0)
# Requirement already satisfied: setuptools>=52.0.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (65.3.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (1.8.1)
# Requirement already satisfied: torchpack>=0.3.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (0.3.1)
# Requirement already satisfied: qiskit>=0.32.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (0.38.0)
# Requirement already satisfied: matplotlib>=3.3.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (3.4.1)
# Requirement already satisfied: pathos>=0.2.7 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (0.2.9)
# Requirement already satisfied: pylatexenc>=2.10 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchquantum==0.1.2) (2.10)
# Requirement already satisfied: cycler>=0.10 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from matplotlib>=3.3.2->torchquantum==0.1.2) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from matplotlib>=3.3.2->torchquantum==0.1.2) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from matplotlib>=3.3.2->torchquantum==0.1.2) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from matplotlib>=3.3.2->torchquantum==0.1.2) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from matplotlib>=3.3.2->torchquantum==0.1.2) (2.8.1)
# Requirement already satisfied: six in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.3.2->torchquantum==0.1.2) (1.15.0)
# Requirement already satisfied: dill>=0.3.5.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from pathos>=0.2.7->torchquantum==0.1.2) (0.3.5.1)
# Requirement already satisfied: multiprocess>=0.70.13 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from pathos>=0.2.7->torchquantum==0.1.2) (0.70.13)
# Requirement already satisfied: ppft>=1.7.6.5 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from pathos>=0.2.7->torchquantum==0.1.2) (1.7.6.5)
# Requirement already satisfied: pox>=0.3.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from pathos>=0.2.7->torchquantum==0.1.2) (0.3.1)
# Requirement already satisfied: qiskit-aer==0.11.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit>=0.32.0->torchquantum==0.1.2) (0.11.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit>=0.32.0->torchquantum==0.1.2) (0.19.2)
# Requirement already satisfied: qiskit-terra==0.21.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit>=0.32.0->torchquantum==0.1.2) (0.21.2)
# Requirement already satisfied: scipy>=1.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-aer==0.11.0->qiskit>=0.32.0->torchquantum==0.1.2) (1.6.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.26.4)
# Requirement already satisfied: websockets>=10.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (10.3)
# Requirement already satisfied: websocket-client>=1.0.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.4.1)
# Requirement already satisfied: requests>=2.19 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (2.25.1)
# Requirement already satisfied: ply>=3.10 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (3.11)
# Requirement already satisfied: retworkx>=0.11.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (0.11.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (4.0.0)
# Requirement already satisfied: psutil>=5 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (5.8.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.1.1)
# Requirement already satisfied: sympy>=1.3 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.7.1)
# Requirement already satisfied: symengine>=0.9 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (0.9.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (2020.12.5)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.14.5)
# Requirement already satisfied: pycparser in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit>=0.32.0->torchquantum==0.1.2) (2.20)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from stevedore>=3.0.0->qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (5.10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.21.2->qiskit>=0.32.0->torchquantum==0.1.2) (1.2.1)
# Requirement already satisfied: typing-extensions in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torch>=1.8.0->torchquantum==0.1.2) (3.7.4.3)
# Requirement already satisfied: loguru in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (0.6.0)
# Requirement already satisfied: multimethod in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (1.8)
# Requirement already satisfied: pyyaml in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (5.3.1)
# Requirement already satisfied: tensorboard in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (2.9.1)
# Requirement already satisfied: tensorpack in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (0.11)
# Requirement already satisfied: h5py in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (3.1.0)
# Requirement already satisfied: toml in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from torchpack>=0.3.0->torchquantum==0.1.2) (0.10.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (3.15.7)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.28.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (0.36.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.8.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (4.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->torchpack>=0.3.0->torchquantum==0.1.2) (3.1.0)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorpack->torchpack>=0.3.0->torchquantum==0.1.2) (1.0.4)
# Requirement already satisfied: msgpack-numpy>=0.4.4.2 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorpack->torchpack>=0.3.0->torchquantum==0.1.2) (0.4.8)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorpack->torchpack>=0.3.0->torchquantum==0.1.2) (0.8.10)
# Requirement already satisfied: pyzmq>=16 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorpack->torchpack>=0.3.0->torchquantum==0.1.2) (22.3.0)
# Requirement already satisfied: termcolor>=1.1 in /Users/mohammad/miniforge3/lib/python3.8/site-packages (from tensorpack->torchpack>=0.3.0->torchquantum==0.1.2) (1.1.0)
# Installing collected packages: torchquantum
#   Attempting uninstall: torchquantum
#     Found existing installation: torchquantum 0.1.2
#     Uninstalling torchquantum-0.1.2:
#       Successfully uninstalled torchquantum-0.1.2
#   Running setup.py develop for torchquantum
# Successfully installed torchquantum

# %% [markdown]
# ## Setup

# %% [markdown]
# Our code requires torchquantum lib,and pytorch. We need torch function from torch.nn.functional, optimizers(optim), torchquantum module.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import torch.nn as nn
import torchquantum as tq
import torchquantum.functional as tqf

# %% [markdown]
# ## Build Quantum LSTM

# %% [markdown]
# Before the rise of the transformer, recurrent neural networks, especially Long Short-Term Memory (LSTM), were the most successful techniques for generating and analyzing sequential data. LSTM uses a combination of “memory” and “statefulness” tricks to understand which parts of the input are relevant to compute the output.[1]

# %% [markdown]
# ![Screen%20Shot%202022-09-15%20at%2010.25.20%20PM-2.png](attachment:Screen%20Shot%202022-09-15%20at%2010.25.20%20PM-2.png)<figcaption align = "center"> LSTM architecture </figcaption>

# %% [markdown]
# To convert classical LSTM to quantum-enhanced LSTM (QLSTM) each of the classical linear operations Wf, Wi, WC, and Wo is replaced by a hybrid quantum-classical component that consists of a Variational Quantum Circuit sandwiched between classical layers.
# [1]

# %% [markdown]
# Typically a Quantum Neural Network module consists of three parts: encoder, ansatz, and measurement. We can create an encoder by passing a list of gates to tq.GeneralEncoder. Each entry in the list contains input_idx, func, and wires. Here, each qubit has a rotation-X gate. 4 RX gates in total. They can encode the 4 input data to the quantum state. Then we choose ansatz such that they are entangled between each other, rotated by an arbitrary angle. Finally, we perform Pauli-Z measurements on each qubit by creating a tq.MeasureAll module and passing tq.PauliZ to it. The measure function will return four expectation values from four qubits.

# %%
class QLSTM(nn.Module):
    
     
        # use 'qiskit.ibmq' instead to run on hardware

    class QLayer_forget(tq.QuantumModule):
        def __init__(self):
            super().__init__()    
            self.n_wires = 4
            self.encoder = tq.GeneralEncoder(
        [   {'input_idx': [0], 'func': 'rx', 'wires': [0]},
            {'input_idx': [1], 'func': 'rx', 'wires': [1]},
            {'input_idx': [2], 'func': 'rx', 'wires': [2]},
            {'input_idx': [3], 'func': 'rx', 'wires': [3]},
        ])
            self.rx0 = tq.RX(has_params=True, trainable=True)
            self.rx1 = tq.RX(has_params=True, trainable=True)
            self.rx2 = tq.RX(has_params=True, trainable=True)
            self.rx3 = tq.RX(has_params=True, trainable=True)
            self.measure = tq.MeasureAll(tq.PauliZ)
        def forward (self, x, q_device: tq.QuantumDevice):
            self.q_device = q_device
            self.encoder(self.q_device, x)
            self.rx0(self.q_device, wires=0)
            self.rx1(self.q_device, wires=1)
            self.rx2(self.q_device, wires=2)
            self.rx3(self.q_device, wires=3)
            for k in range(self.n_wires):
                if k==self.n_wires-1:
                    tqf.cnot(self.q_device, wires=[k, 0]) 
                else:
                    tqf.cnot(self.q_device, wires=[k, k+1])
            return(self.measure(self.q_device))
    class QLayer_input(tq.QuantumModule):
        def __init__(self):
            super().__init__()    
            self.n_wires = 4
            self.encoder = tq.GeneralEncoder(
        [   {'input_idx': [0], 'func': 'rx', 'wires': [0]},
            {'input_idx': [1], 'func': 'rx', 'wires': [1]},
            {'input_idx': [2], 'func': 'rx', 'wires': [2]},
            {'input_idx': [3], 'func': 'rx', 'wires': [2]},
        ])
            self.rx0 = tq.RX(has_params=True, trainable=True)
            self.rx1 = tq.RX(has_params=True, trainable=True)
            self.rx2 = tq.RX(has_params=True, trainable=True)
            self.rx3 = tq.RX(has_params=True, trainable=True)
            self.measure = tq.MeasureAll(tq.PauliZ)
        def forward (self, x, q_device: tq.QuantumDevice):
            self.q_device = q_device
            self.encoder(self.q_device, x)
            self.rx0(self.q_device, wires=0)
            self.rx1(self.q_device, wires=1)
            self.rx2(self.q_device, wires=2)
            self.rx3(self.q_device, wires=3)
            for k in range(self.n_wires):
                if k==self.n_wires-1:
                    tqf.cnot(self.q_device, wires=[k, 0]) 
                else:
                    tqf.cnot(self.q_device, wires=[k, k+1])
            return(self.measure(self.q_device))
    class QLayer_update(tq.QuantumModule):
        def __init__(self):
            super().__init__()    
            self.n_wires = 4
            self.encoder = tq.GeneralEncoder(
        [   {'input_idx': [0], 'func': 'rx', 'wires': [0]},
            {'input_idx': [1], 'func': 'rx', 'wires': [1]},
            {'input_idx': [2], 'func': 'rx', 'wires': [2]},
            {'input_idx': [3], 'func': 'rx', 'wires': [2]},
        ])
            self.rx0 = tq.RX(has_params=True, trainable=True)
            self.rx1 = tq.RX(has_params=True, trainable=True)
            self.rx2 = tq.RX(has_params=True, trainable=True)
            self.rx3 = tq.RX(has_params=True, trainable=True)
            self.measure = tq.MeasureAll(tq.PauliZ)
        def forward (self, x, q_device: tq.QuantumDevice):
            self.q_device = q_device
            self.encoder(self.q_device, x)
            self.rx0(self.q_device, wires=0)
            self.rx1(self.q_device, wires=1)
            self.rx2(self.q_device, wires=2)
            self.rx3(self.q_device, wires=3)
            for k in range(self.n_wires):
                if k==self.n_wires-1:
                    tqf.cnot(self.q_device, wires=[k, 0]) 
                else:
                    tqf.cnot(self.q_device, wires=[k, k+1])
            return(self.measure(self.q_device))
    class QLayer_output(tq.QuantumModule):
        def __init__(self):
            super().__init__()    
            self.n_wires = 4
            self.encoder = tq.GeneralEncoder(
        [   {'input_idx': [0], 'func': 'rx', 'wires': [0]},
            {'input_idx': [1], 'func': 'rx', 'wires': [1]},
            {'input_idx': [2], 'func': 'rx', 'wires': [2]},
            {'input_idx': [3], 'func': 'rx', 'wires': [2]},
        ])
            self.rx0 = tq.RX(has_params=True, trainable=True)
            self.rx1 = tq.RX(has_params=True, trainable=True)
            self.rx2 = tq.RX(has_params=True, trainable=True)
            self.rx3 = tq.RX(has_params=True, trainable=True)
            self.measure = tq.MeasureAll(tq.PauliZ)
        def forward (self, x, q_device: tq.QuantumDevice):
            self.q_device = q_device
            self.encoder(self.q_device, x)
            self.rx0(self.q_device, wires=0)
            self.rx1(self.q_device, wires=1)
            self.rx2(self.q_device, wires=2)
            self.rx3(self.q_device, wires=3)
            for k in range(self.n_wires):
                if k==self.n_wires-1:
                    tqf.cnot(self.q_device, wires=[k, 0]) 
                else:
                    tqf.cnot(self.q_device, wires=[k, k+1])
            return(self.measure(self.q_device))
    def __init__(self, 
                input_size, 
                hidden_size, 
                n_qubits=4,
                n_qlayers=1,
                batch_first=True,
                return_sequences=False, 
                return_state=False,
                backend="default.qubit"):
        super(QLSTM, self).__init__()
        self.n_inputs = input_size
        self.hidden_size = hidden_size
        self.concat_size = self.n_inputs + self.hidden_size
        self.n_qubits = n_qubits
        self.n_qlayers = n_qlayers
        self.backend = backend  # "default.qubit", "qiskit.basicaer", "qiskit.ibm"

        self.batch_first = batch_first
        self.return_sequences = return_sequences
        self.return_state = return_state
        #self.q_layer = self.QLayer()
        self.dev = tq.QuantumDevice(self.n_qubits)


        self.clayer_in = torch.nn.Linear(self.concat_size, n_qubits)
        self.VQC = {
            'forget':self.QLayer_forget(),
            'input': self.QLayer_input(),
            'update':self.QLayer_update(),
            'output':self.QLayer_output()
        }
        self.clayer_out = torch.nn.Linear(self.n_qubits, self.hidden_size)
        #self.clayer_out = [torch.nn.Linear(n_qubits, self.hidden_size) for _ in range(4)]

    def forward(self, x, init_states=None):
        '''
        x.shape is (batch_size, seq_length, feature_size)
        recurrent_activation -> sigmoid
        activation -> tanh
        '''
        if self.batch_first is True:
            batch_size, seq_length, features_size = x.size()
        else:
            seq_length, batch_size, features_size = x.size()

        hidden_seq = []
        if init_states is None:
            h_t = torch.zeros(batch_size, self.hidden_size)  # hidden state (output)
            c_t = torch.zeros(batch_size, self.hidden_size)  # cell state
        else:
            # for now we ignore the fact that in PyTorch you can stack multiple RNNs
            # so we take only the first elements of the init_states tuple init_states[0][0], init_states[1][0]
            h_t, c_t = init_states
            h_t = h_t[0]
            c_t = c_t[0]

        for t in range(seq_length):
            # get features from the t-th element in seq, for all entries in the batch
            x_t = x[:, t, :]
            
            # Concatenate input and hidden state
            v_t = torch.cat((h_t, x_t), dim=1)

            # match qubit dimension
            y_t = self.clayer_in(v_t)

            f_t = torch.sigmoid(self.clayer_out(self.VQC['forget'](y_t,self.dev)))  # forget block
            i_t = torch.sigmoid(self.clayer_out(self.VQC['input'](y_t,self.dev)))  # input block
            g_t = torch.tanh(self.clayer_out(self.VQC['update'](y_t,self.dev)))  # update block
            o_t = torch.sigmoid(self.clayer_out(self.VQC['output'](y_t,self.dev))) # output block

            c_t = (f_t * c_t) + (i_t * g_t)
            h_t = o_t * torch.tanh(c_t)

            hidden_seq.append(h_t.unsqueeze(0))
        hidden_seq = torch.cat(hidden_seq, dim=0)
        hidden_seq = hidden_seq.transpose(0, 1).contiguous()
        return hidden_seq, (h_t, c_t)

# %% [markdown]
# ## POS_tagging

# %% [markdown]
# Here we define the possible tags: determinant, noun, verb.

# %%
tag_to_ix = {"DET": 0, "NN": 1, "V": 2}  # Assign each tag with a unique index
ix_to_tag = {i:k for k,i in tag_to_ix.items()}

# %% [markdown]
# The function below tokenizes the sentence and matches the label to each word.

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %% [markdown]
# Now we can prepare the input dataset.

# %%
training_data = [
    # Tags are: DET - determiner; NN - noun; V - verb
    # For example, the word "The" is a determiner
    ("The dog ate the apple".split(), ["DET", "NN", "V", "DET", "NN"]),
    ("Everybody read that book".split(), ["NN", "V", "DET", "NN"])
]
word_to_ix = {}

# For each words-list (sentence) and tags-list in each tuple of training_data
for sent, tags in training_data:
    for word in sent:
        if word not in word_to_ix:  # word has not been assigned an index yet
            word_to_ix[word] = len(word_to_ix)  # Assign each word with a unique index

print(f"Vocabulary: {word_to_ix}")
print(f"Entities: {ix_to_tag}")
# Out:
# Vocabulary: {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'that': 7, 'book': 8}
# Entities: {0: 'DET', 1: 'NN', 2: 'V'}

# %% [markdown]
# The idea is to pass the two sequences through the LSTM, which will output the hidden array of vectors [h_0, h_1, h_2, h_3, h_4], one for each word. A dense layer “head” is attached to the LSTM’s outputs to calculate the probability that each word may be a determinant, noun or verb.

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, n_qubits=0):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        if n_qubits > 0:
            print("Tagger will use Quantum LSTM")
            self.lstm = QLSTM(embedding_dim, hidden_dim, n_qubits=n_qubits)
        else:
            print("Tagger will use Classical LSTM")
            self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_logits = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_logits, dim=1)
        return tag_scores

# %%
embedding_dim = 8
hidden_dim = 6
n_epochs = 300

# %%
model_classical = LSTMTagger(embedding_dim, 
                        hidden_dim, 
                        vocab_size=len(word_to_ix), 
                        tagset_size=len(tag_to_ix), 
                        n_qubits=0)
# Out:
# Tagger will use Classical LSTM

# %% [markdown]
# ## Training

# %% [markdown]
# Following the example from the PyTorch website, we train the two networks (classical and quantum LSTM) for 300 epochs.

# %%
def train(model, n_epochs):
    loss_function = nn.NLLLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1)

    history = {
        'loss': [],
        'acc': []
    }
    for epoch in range(n_epochs):
        losses = []
        preds = []
        targets = []
        for sentence, tags in training_data:
            # Step 1. Remember that Pytorch accumulates gradients.
            # We need to clear them out before each instance
            model.zero_grad()

            # Step 2. Get our inputs ready for the network, that is, turn them into
            # Tensors of word indices.
            sentence_in = prepare_sequence(sentence, word_to_ix)
            labels = prepare_sequence(tags, tag_to_ix)

            # Step 3. Run our forward pass.
            tag_scores = model(sentence_in)

            # Step 4. Compute the loss, gradients, and update the parameters by
            #  calling optimizer.step()
            loss = loss_function(tag_scores, labels)
            loss.backward()
            optimizer.step()
            losses.append(float(loss))
            
            probs = torch.softmax(tag_scores, dim=-1)
            preds.append(probs.argmax(dim=-1))
            targets.append(labels)

        avg_loss = np.mean(losses)
        history['loss'].append(avg_loss)
        
        preds = torch.cat(preds)
        targets = torch.cat(targets)
        corrects = (preds == targets)
        accuracy = corrects.sum().float() / float(targets.size(0) )
        history['acc'].append(accuracy)

        print(f"Epoch {epoch+1} / {n_epochs}: Loss = {avg_loss:.3f} Acc = {accuracy:.2f}")

    return history

# %%
history_classical = train(model_classical, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.089 Acc = 0.22
# Epoch 2 / 300: Loss = 1.079 Acc = 0.44
# Epoch 3 / 300: Loss = 1.070 Acc = 0.44
# Epoch 4 / 300: Loss = 1.062 Acc = 0.56
# Epoch 5 / 300: Loss = 1.055 Acc = 0.67
# Epoch 6 / 300: Loss = 1.048 Acc = 0.67
# Epoch 7 / 300: Loss = 1.042 Acc = 0.67
# Epoch 8 / 300: Loss = 1.036 Acc = 0.44
# Epoch 9 / 300: Loss = 1.031 Acc = 0.44
# Epoch 10 / 300: Loss = 1.025 Acc = 0.44
# Epoch 11 / 300: Loss = 1.021 Acc = 0.44
# Epoch 12 / 300: Loss = 1.016 Acc = 0.44
# Epoch 13 / 300: Loss = 1.011 Acc = 0.44
# Epoch 14 / 300: Loss = 1.007 Acc = 0.44
# Epoch 15 / 300: Loss = 1.002 Acc = 0.44
# Epoch 16 / 300: Loss = 0.998 Acc = 0.44
# Epoch 17 / 300: Loss = 0.993 Acc = 0.44
# Epoch 18 / 300: Loss = 0.989 Acc = 0.44
# Epoch 19 / 300: Loss = 0.984 Acc = 0.44
# Epoch 20 / 300: Loss = 0.980 Acc = 0.56
# Epoch 21 / 300: Loss = 0.975 Acc = 0.56
# Epoch 22 / 300: Loss = 0.970 Acc = 0.56
# Epoch 23 / 300: Loss = 0.965 Acc = 0.56
# Epoch 24 / 300: Loss = 0.960 Acc = 0.56
# Epoch 25 / 300: Loss = 0.955 Acc = 0.56
# Epoch 26 / 300: Loss = 0.949 Acc = 0.56
# Epoch 27 / 300: Loss = 0.944 Acc = 0.56
# Epoch 28 / 300: Loss = 0.938 Acc = 0.56
# Epoch 29 / 300: Loss = 0.932 Acc = 0.67
# Epoch 30 / 300: Loss = 0.926 Acc = 0.67
# Epoch 31 / 300: Loss = 0.919 Acc = 0.67
# Epoch 32 / 300: Loss = 0.913 Acc = 0.67
# Epoch 33 / 300: Loss = 0.906 Acc = 0.67
# Epoch 34 / 300: Loss = 0.899 Acc = 0.67
# Epoch 35 / 300: Loss = 0.891 Acc = 0.67
# Epoch 36 / 300: Loss = 0.884 Acc = 0.67
# Epoch 37 / 300: Loss = 0.876 Acc = 0.67
# Epoch 38 / 300: Loss = 0.868 Acc = 0.67
# Epoch 39 / 300: Loss = 0.860 Acc = 0.67
# Epoch 40 / 300: Loss = 0.852 Acc = 0.67
# Epoch 41 / 300: Loss = 0.843 Acc = 0.67
# Epoch 42 / 300: Loss = 0.834 Acc = 0.78
# Epoch 43 / 300: Loss = 0.825 Acc = 0.78
# Epoch 44 / 300: Loss = 0.816 Acc = 0.78
# Epoch 45 / 300: Loss = 0.807 Acc = 0.78
# Epoch 46 / 300: Loss = 0.797 Acc = 0.78
# Epoch 47 / 300: Loss = 0.787 Acc = 0.78
# Epoch 48 / 300: Loss = 0.777 Acc = 0.78
# Epoch 49 / 300: Loss = 0.767 Acc = 0.78
# Epoch 50 / 300: Loss = 0.757 Acc = 0.78
# Epoch 51 / 300: Loss = 0.746 Acc = 0.78
# Epoch 52 / 300: Loss = 0.736 Acc = 0.78
# Epoch 53 / 300: Loss = 0.725 Acc = 0.78
# Epoch 54 / 300: Loss = 0.714 Acc = 0.78
# Epoch 55 / 300: Loss = 0.703 Acc = 0.78
# Epoch 56 / 300: Loss = 0.692 Acc = 0.78
# Epoch 57 / 300: Loss = 0.681 Acc = 0.78
# Epoch 58 / 300: Loss = 0.669 Acc = 0.78
# Epoch 59 / 300: Loss = 0.658 Acc = 0.78
# Epoch 60 / 300: Loss = 0.646 Acc = 0.89
# Epoch 61 / 300: Loss = 0.635 Acc = 0.89
# Epoch 62 / 300: Loss = 0.623 Acc = 0.89
# Epoch 63 / 300: Loss = 0.612 Acc = 0.89
# Epoch 64 / 300: Loss = 0.600 Acc = 0.89
# Epoch 65 / 300: Loss = 0.589 Acc = 0.89
# Epoch 66 / 300: Loss = 0.577 Acc = 0.89
# Epoch 67 / 300: Loss = 0.566 Acc = 0.89
# Epoch 68 / 300: Loss = 0.554 Acc = 0.89
# Epoch 69 / 300: Loss = 0.543 Acc = 0.89
# Epoch 70 / 300: Loss = 0.531 Acc = 0.89
# Epoch 71 / 300: Loss = 0.520 Acc = 0.89
# Epoch 72 / 300: Loss = 0.509 Acc = 0.89
# Epoch 73 / 300: Loss = 0.497 Acc = 0.89
# Epoch 74 / 300: Loss = 0.486 Acc = 0.89
# Epoch 75 / 300: Loss = 0.476 Acc = 0.89
# Epoch 76 / 300: Loss = 0.465 Acc = 0.89
# Epoch 77 / 300: Loss = 0.454 Acc = 0.89
# Epoch 78 / 300: Loss = 0.444 Acc = 1.00
# Epoch 79 / 300: Loss = 0.433 Acc = 1.00
# Epoch 80 / 300: Loss = 0.423 Acc = 1.00
# Epoch 81 / 300: Loss = 0.413 Acc = 1.00
# Epoch 82 / 300: Loss = 0.404 Acc = 1.00
# Epoch 83 / 300: Loss = 0.394 Acc = 1.00
# Epoch 84 / 300: Loss = 0.385 Acc = 1.00
# Epoch 85 / 300: Loss = 0.375 Acc = 1.00
# Epoch 86 / 300: Loss = 0.366 Acc = 1.00
# Epoch 87 / 300: Loss = 0.357 Acc = 1.00
# Epoch 88 / 300: Loss = 0.349 Acc = 1.00
# Epoch 89 / 300: Loss = 0.340 Acc = 1.00
# Epoch 90 / 300: Loss = 0.332 Acc = 1.00
# Epoch 91 / 300: Loss = 0.324 Acc = 1.00
# Epoch 92 / 300: Loss = 0.317 Acc = 1.00
# Epoch 93 / 300: Loss = 0.309 Acc = 1.00
# Epoch 94 / 300: Loss = 0.302 Acc = 1.00
# Epoch 95 / 300: Loss = 0.294 Acc = 1.00
# Epoch 96 / 300: Loss = 0.287 Acc = 1.00
# Epoch 97 / 300: Loss = 0.281 Acc = 1.00
# Epoch 98 / 300: Loss = 0.274 Acc = 1.00
# Epoch 99 / 300: Loss = 0.267 Acc = 1.00
# Epoch 100 / 300: Loss = 0.261 Acc = 1.00
# Epoch 101 / 300: Loss = 0.255 Acc = 1.00
# Epoch 102 / 300: Loss = 0.249 Acc = 1.00
# Epoch 103 / 300: Loss = 0.244 Acc = 1.00
# Epoch 104 / 300: Loss = 0.238 Acc = 1.00
# Epoch 105 / 300: Loss = 0.233 Acc = 1.00
# Epoch 106 / 300: Loss = 0.227 Acc = 1.00
# Epoch 107 / 300: Loss = 0.222 Acc = 1.00
# Epoch 108 / 300: Loss = 0.217 Acc = 1.00
# Epoch 109 / 300: Loss = 0.213 Acc = 1.00
# Epoch 110 / 300: Loss = 0.208 Acc = 1.00
# Epoch 111 / 300: Loss = 0.203 Acc = 1.00
# Epoch 112 / 300: Loss = 0.199 Acc = 1.00
# Epoch 113 / 300: Loss = 0.195 Acc = 1.00
# Epoch 114 / 300: Loss = 0.191 Acc = 1.00
# Epoch 115 / 300: Loss = 0.187 Acc = 1.00
# Epoch 116 / 300: Loss = 0.183 Acc = 1.00
# Epoch 117 / 300: Loss = 0.179 Acc = 1.00
# Epoch 118 / 300: Loss = 0.175 Acc = 1.00
# Epoch 119 / 300: Loss = 0.172 Acc = 1.00
# Epoch 120 / 300: Loss = 0.169 Acc = 1.00
# Epoch 121 / 300: Loss = 0.165 Acc = 1.00
# Epoch 122 / 300: Loss = 0.162 Acc = 1.00
# Epoch 123 / 300: Loss = 0.159 Acc = 1.00
# Epoch 124 / 300: Loss = 0.156 Acc = 1.00
# Epoch 125 / 300: Loss = 0.153 Acc = 1.00
# Epoch 126 / 300: Loss = 0.150 Acc = 1.00
# Epoch 127 / 300: Loss = 0.147 Acc = 1.00
# Epoch 128 / 300: Loss = 0.144 Acc = 1.00
# Epoch 129 / 300: Loss = 0.142 Acc = 1.00
# Epoch 130 / 300: Loss = 0.139 Acc = 1.00
# Epoch 131 / 300: Loss = 0.137 Acc = 1.00
# Epoch 132 / 300: Loss = 0.134 Acc = 1.00
# Epoch 133 / 300: Loss = 0.132 Acc = 1.00
# Epoch 134 / 300: Loss = 0.130 Acc = 1.00
# Epoch 135 / 300: Loss = 0.127 Acc = 1.00
# Epoch 136 / 300: Loss = 0.125 Acc = 1.00
# Epoch 137 / 300: Loss = 0.123 Acc = 1.00
# Epoch 138 / 300: Loss = 0.121 Acc = 1.00
# Epoch 139 / 300: Loss = 0.119 Acc = 1.00
# Epoch 140 / 300: Loss = 0.117 Acc = 1.00
# Epoch 141 / 300: Loss = 0.115 Acc = 1.00
# Epoch 142 / 300: Loss = 0.113 Acc = 1.00
# Epoch 143 / 300: Loss = 0.112 Acc = 1.00
# Epoch 144 / 300: Loss = 0.110 Acc = 1.00
# Epoch 145 / 300: Loss = 0.108 Acc = 1.00
# Epoch 146 / 300: Loss = 0.107 Acc = 1.00
# Epoch 147 / 300: Loss = 0.105 Acc = 1.00
# Epoch 148 / 300: Loss = 0.103 Acc = 1.00
# Epoch 149 / 300: Loss = 0.102 Acc = 1.00
# Epoch 150 / 300: Loss = 0.100 Acc = 1.00
# Epoch 151 / 300: Loss = 0.099 Acc = 1.00
# Epoch 152 / 300: Loss = 0.097 Acc = 1.00
# Epoch 153 / 300: Loss = 0.096 Acc = 1.00
# Epoch 154 / 300: Loss = 0.095 Acc = 1.00
# Epoch 155 / 300: Loss = 0.093 Acc = 1.00
# Epoch 156 / 300: Loss = 0.092 Acc = 1.00
# Epoch 157 / 300: Loss = 0.091 Acc = 1.00
# Epoch 158 / 300: Loss = 0.089 Acc = 1.00
# Epoch 159 / 300: Loss = 0.088 Acc = 1.00
# Epoch 160 / 300: Loss = 0.087 Acc = 1.00
# Epoch 161 / 300: Loss = 0.086 Acc = 1.00
# Epoch 162 / 300: Loss = 0.085 Acc = 1.00
# Epoch 163 / 300: Loss = 0.084 Acc = 1.00
# Epoch 164 / 300: Loss = 0.083 Acc = 1.00
# Epoch 165 / 300: Loss = 0.082 Acc = 1.00
# Epoch 166 / 300: Loss = 0.080 Acc = 1.00
# Epoch 167 / 300: Loss = 0.079 Acc = 1.00
# Epoch 168 / 300: Loss = 0.078 Acc = 1.00
# Epoch 169 / 300: Loss = 0.077 Acc = 1.00
# Epoch 170 / 300: Loss = 0.077 Acc = 1.00
# Epoch 171 / 300: Loss = 0.076 Acc = 1.00
# Epoch 172 / 300: Loss = 0.075 Acc = 1.00
# Epoch 173 / 300: Loss = 0.074 Acc = 1.00
# Epoch 174 / 300: Loss = 0.073 Acc = 1.00
# Epoch 175 / 300: Loss = 0.072 Acc = 1.00
# Epoch 176 / 300: Loss = 0.071 Acc = 1.00
# Epoch 177 / 300: Loss = 0.070 Acc = 1.00
# Epoch 178 / 300: Loss = 0.070 Acc = 1.00
# Epoch 179 / 300: Loss = 0.069 Acc = 1.00
# Epoch 180 / 300: Loss = 0.068 Acc = 1.00
# Epoch 181 / 300: Loss = 0.067 Acc = 1.00
# Epoch 182 / 300: Loss = 0.067 Acc = 1.00
# Epoch 183 / 300: Loss = 0.066 Acc = 1.00
# Epoch 184 / 300: Loss = 0.065 Acc = 1.00
# Epoch 185 / 300: Loss = 0.064 Acc = 1.00
# Epoch 186 / 300: Loss = 0.064 Acc = 1.00
# Epoch 187 / 300: Loss = 0.063 Acc = 1.00
# Epoch 188 / 300: Loss = 0.062 Acc = 1.00
# Epoch 189 / 300: Loss = 0.062 Acc = 1.00
# Epoch 190 / 300: Loss = 0.061 Acc = 1.00
# Epoch 191 / 300: Loss = 0.060 Acc = 1.00
# Epoch 192 / 300: Loss = 0.060 Acc = 1.00
# Epoch 193 / 300: Loss = 0.059 Acc = 1.00
# Epoch 194 / 300: Loss = 0.059 Acc = 1.00
# Epoch 195 / 300: Loss = 0.058 Acc = 1.00
# Epoch 196 / 300: Loss = 0.057 Acc = 1.00
# Epoch 197 / 300: Loss = 0.057 Acc = 1.00
# Epoch 198 / 300: Loss = 0.056 Acc = 1.00
# Epoch 199 / 300: Loss = 0.056 Acc = 1.00
# Epoch 200 / 300: Loss = 0.055 Acc = 1.00
# Epoch 201 / 300: Loss = 0.055 Acc = 1.00
# Epoch 202 / 300: Loss = 0.054 Acc = 1.00
# Epoch 203 / 300: Loss = 0.054 Acc = 1.00
# Epoch 204 / 300: Loss = 0.053 Acc = 1.00
# Epoch 205 / 300: Loss = 0.053 Acc = 1.00
# Epoch 206 / 300: Loss = 0.052 Acc = 1.00
# Epoch 207 / 300: Loss = 0.052 Acc = 1.00
# Epoch 208 / 300: Loss = 0.051 Acc = 1.00
# Epoch 209 / 300: Loss = 0.051 Acc = 1.00
# Epoch 210 / 300: Loss = 0.050 Acc = 1.00
# Epoch 211 / 300: Loss = 0.050 Acc = 1.00
# Epoch 212 / 300: Loss = 0.049 Acc = 1.00
# Epoch 213 / 300: Loss = 0.049 Acc = 1.00
# Epoch 214 / 300: Loss = 0.048 Acc = 1.00
# Epoch 215 / 300: Loss = 0.048 Acc = 1.00
# Epoch 216 / 300: Loss = 0.048 Acc = 1.00
# Epoch 217 / 300: Loss = 0.047 Acc = 1.00
# Epoch 218 / 300: Loss = 0.047 Acc = 1.00
# Epoch 219 / 300: Loss = 0.046 Acc = 1.00
# Epoch 220 / 300: Loss = 0.046 Acc = 1.00
# Epoch 221 / 300: Loss = 0.046 Acc = 1.00
# Epoch 222 / 300: Loss = 0.045 Acc = 1.00
# Epoch 223 / 300: Loss = 0.045 Acc = 1.00
# Epoch 224 / 300: Loss = 0.045 Acc = 1.00
# Epoch 225 / 300: Loss = 0.044 Acc = 1.00
# Epoch 226 / 300: Loss = 0.044 Acc = 1.00
# Epoch 227 / 300: Loss = 0.043 Acc = 1.00
# Epoch 228 / 300: Loss = 0.043 Acc = 1.00
# Epoch 229 / 300: Loss = 0.043 Acc = 1.00
# Epoch 230 / 300: Loss = 0.042 Acc = 1.00
# Epoch 231 / 300: Loss = 0.042 Acc = 1.00
# Epoch 232 / 300: Loss = 0.042 Acc = 1.00
# Epoch 233 / 300: Loss = 0.041 Acc = 1.00
# Epoch 234 / 300: Loss = 0.041 Acc = 1.00
# Epoch 235 / 300: Loss = 0.041 Acc = 1.00
# Epoch 236 / 300: Loss = 0.041 Acc = 1.00
# Epoch 237 / 300: Loss = 0.040 Acc = 1.00
# Epoch 238 / 300: Loss = 0.040 Acc = 1.00
# Epoch 239 / 300: Loss = 0.040 Acc = 1.00
# Epoch 240 / 300: Loss = 0.039 Acc = 1.00
# Epoch 241 / 300: Loss = 0.039 Acc = 1.00
# Epoch 242 / 300: Loss = 0.039 Acc = 1.00
# Epoch 243 / 300: Loss = 0.038 Acc = 1.00
# Epoch 244 / 300: Loss = 0.038 Acc = 1.00
# Epoch 245 / 300: Loss = 0.038 Acc = 1.00
# Epoch 246 / 300: Loss = 0.038 Acc = 1.00
# Epoch 247 / 300: Loss = 0.037 Acc = 1.00
# Epoch 248 / 300: Loss = 0.037 Acc = 1.00
# Epoch 249 / 300: Loss = 0.037 Acc = 1.00
# Epoch 250 / 300: Loss = 0.037 Acc = 1.00
# Epoch 251 / 300: Loss = 0.036 Acc = 1.00
# Epoch 252 / 300: Loss = 0.036 Acc = 1.00
# Epoch 253 / 300: Loss = 0.036 Acc = 1.00
# Epoch 254 / 300: Loss = 0.036 Acc = 1.00
# Epoch 255 / 300: Loss = 0.035 Acc = 1.00
# Epoch 256 / 300: Loss = 0.035 Acc = 1.00
# Epoch 257 / 300: Loss = 0.035 Acc = 1.00
# Epoch 258 / 300: Loss = 0.035 Acc = 1.00
# Epoch 259 / 300: Loss = 0.034 Acc = 1.00
# Epoch 260 / 300: Loss = 0.034 Acc = 1.00
# Epoch 261 / 300: Loss = 0.034 Acc = 1.00
# Epoch 262 / 300: Loss = 0.034 Acc = 1.00
# Epoch 263 / 300: Loss = 0.033 Acc = 1.00
# Epoch 264 / 300: Loss = 0.033 Acc = 1.00
# Epoch 265 / 300: Loss = 0.033 Acc = 1.00
# Epoch 266 / 300: Loss = 0.033 Acc = 1.00
# Epoch 267 / 300: Loss = 0.033 Acc = 1.00
# Epoch 268 / 300: Loss = 0.032 Acc = 1.00
# Epoch 269 / 300: Loss = 0.032 Acc = 1.00
# Epoch 270 / 300: Loss = 0.032 Acc = 1.00
# Epoch 271 / 300: Loss = 0.032 Acc = 1.00
# Epoch 272 / 300: Loss = 0.032 Acc = 1.00
# Epoch 273 / 300: Loss = 0.031 Acc = 1.00
# Epoch 274 / 300: Loss = 0.031 Acc = 1.00
# Epoch 275 / 300: Loss = 0.031 Acc = 1.00
# Epoch 276 / 300: Loss = 0.031 Acc = 1.00
# Epoch 277 / 300: Loss = 0.031 Acc = 1.00
# Epoch 278 / 300: Loss = 0.030 Acc = 1.00
# Epoch 279 / 300: Loss = 0.030 Acc = 1.00
# Epoch 280 / 300: Loss = 0.030 Acc = 1.00
# Epoch 281 / 300: Loss = 0.030 Acc = 1.00
# Epoch 282 / 300: Loss = 0.030 Acc = 1.00
# Epoch 283 / 300: Loss = 0.030 Acc = 1.00
# Epoch 284 / 300: Loss = 0.029 Acc = 1.00
# Epoch 285 / 300: Loss = 0.029 Acc = 1.00
# Epoch 286 / 300: Loss = 0.029 Acc = 1.00
# Epoch 287 / 300: Loss = 0.029 Acc = 1.00
# Epoch 288 / 300: Loss = 0.029 Acc = 1.00
# Epoch 289 / 300: Loss = 0.029 Acc = 1.00
# Epoch 290 / 300: Loss = 0.028 Acc = 1.00
# Epoch 291 / 300: Loss = 0.028 Acc = 1.00
# Epoch 292 / 300: Loss = 0.028 Acc = 1.00
# Epoch 293 / 300: Loss = 0.028 Acc = 1.00
# Epoch 294 / 300: Loss = 0.028 Acc = 1.00
# Epoch 295 / 300: Loss = 0.028 Acc = 1.00
# Epoch 296 / 300: Loss = 0.027 Acc = 1.00
# Epoch 297 / 300: Loss = 0.027 Acc = 1.00
# Epoch 298 / 300: Loss = 0.027 Acc = 1.00
# Epoch 299 / 300: Loss = 0.027 Acc = 1.00
# Epoch 300 / 300: Loss = 0.027 Acc = 1.00

# %%
def print_result(model):
    with torch.no_grad():
        input_sentence = training_data[0][0]
        labels = training_data[0][1]
        inputs = prepare_sequence(input_sentence, word_to_ix)
        tag_scores = model(inputs)

        tag_ids = torch.argmax(tag_scores, dim=1).numpy()
        tag_labels = [ix_to_tag[k] for k in tag_ids]
        print(f"Sentence:  {input_sentence}")
        print(f"Labels:    {labels}")
        print(f"Predicted: {tag_labels}")

# %%
print_result(model_classical)
# Out:
# Sentence:  ['The', 'dog', 'ate', 'the', 'apple']
# Labels:    ['DET', 'NN', 'V', 'DET', 'NN']
# Predicted: ['DET', 'NN', 'V', 'DET', 'NN']

# %%
n_qubits = 4

model_quantum = LSTMTagger(embedding_dim, 
                        hidden_dim, 
                        vocab_size=len(word_to_ix), 
                        tagset_size=len(tag_to_ix), 
                        n_qubits=n_qubits)
# Out:
# Tagger will use Quantum LSTM

# %%
history_quantum = train(model_quantum, n_epochs)
# Out:
# /Users/mohammad/miniforge3/lib/python3.8/site-packages/torch/autograd/__init__.py:145: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:219.)
#   Variable._execution_engine.run_backward(
# Epoch 1 / 300: Loss = 1.087 Acc = 0.44
# Epoch 2 / 300: Loss = 1.083 Acc = 0.44
# Epoch 3 / 300: Loss = 1.079 Acc = 0.44
# Epoch 4 / 300: Loss = 1.076 Acc = 0.44
# Epoch 5 / 300: Loss = 1.072 Acc = 0.44
# Epoch 6 / 300: Loss = 1.070 Acc = 0.44
# Epoch 7 / 300: Loss = 1.067 Acc = 0.44
# Epoch 8 / 300: Loss = 1.064 Acc = 0.44
# Epoch 9 / 300: Loss = 1.062 Acc = 0.44
# Epoch 10 / 300: Loss = 1.060 Acc = 0.44
# Epoch 11 / 300: Loss = 1.058 Acc = 0.44
# Epoch 12 / 300: Loss = 1.056 Acc = 0.44
# Epoch 13 / 300: Loss = 1.055 Acc = 0.44
# Epoch 14 / 300: Loss = 1.053 Acc = 0.44
# Epoch 15 / 300: Loss = 1.051 Acc = 0.44
# Epoch 16 / 300: Loss = 1.050 Acc = 0.44
# Epoch 17 / 300: Loss = 1.048 Acc = 0.44
# Epoch 18 / 300: Loss = 1.046 Acc = 0.44
# Epoch 19 / 300: Loss = 1.045 Acc = 0.44
# Epoch 20 / 300: Loss = 1.043 Acc = 0.44
# Epoch 21 / 300: Loss = 1.042 Acc = 0.44
# Epoch 22 / 300: Loss = 1.040 Acc = 0.44
# Epoch 23 / 300: Loss = 1.038 Acc = 0.44
# Epoch 24 / 300: Loss = 1.037 Acc = 0.44
# Epoch 25 / 300: Loss = 1.035 Acc = 0.44
# Epoch 26 / 300: Loss = 1.033 Acc = 0.44
# Epoch 27 / 300: Loss = 1.031 Acc = 0.44
# Epoch 28 / 300: Loss = 1.029 Acc = 0.44
# Epoch 29 / 300: Loss = 1.027 Acc = 0.44
# Epoch 30 / 300: Loss = 1.025 Acc = 0.44
# Epoch 31 / 300: Loss = 1.023 Acc = 0.44
# Epoch 32 / 300: Loss = 1.021 Acc = 0.44
# Epoch 33 / 300: Loss = 1.018 Acc = 0.44
# Epoch 34 / 300: Loss = 1.016 Acc = 0.44
# Epoch 35 / 300: Loss = 1.013 Acc = 0.44
# Epoch 36 / 300: Loss = 1.011 Acc = 0.44
# Epoch 37 / 300: Loss = 1.008 Acc = 0.44
# Epoch 38 / 300: Loss = 1.005 Acc = 0.44
# Epoch 39 / 300: Loss = 1.003 Acc = 0.44
# Epoch 40 / 300: Loss = 1.000 Acc = 0.44
# Epoch 41 / 300: Loss = 0.996 Acc = 0.44
# Epoch 42 / 300: Loss = 0.993 Acc = 0.44
# Epoch 43 / 300: Loss = 0.990 Acc = 0.44
# Epoch 44 / 300: Loss = 0.987 Acc = 0.44
# Epoch 45 / 300: Loss = 0.983 Acc = 0.44
# Epoch 46 / 300: Loss = 0.980 Acc = 0.44
# Epoch 47 / 300: Loss = 0.976 Acc = 0.44
# Epoch 48 / 300: Loss = 0.972 Acc = 0.44
# Epoch 49 / 300: Loss = 0.969 Acc = 0.44
# Epoch 50 / 300: Loss = 0.965 Acc = 0.44
# Epoch 51 / 300: Loss = 0.961 Acc = 0.44
# Epoch 52 / 300: Loss = 0.957 Acc = 0.44
# Epoch 53 / 300: Loss = 0.952 Acc = 0.44
# Epoch 54 / 300: Loss = 0.948 Acc = 0.44
# Epoch 55 / 300: Loss = 0.944 Acc = 0.44
# Epoch 56 / 300: Loss = 0.939 Acc = 0.44
# Epoch 57 / 300: Loss = 0.935 Acc = 0.44
# Epoch 58 / 300: Loss = 0.930 Acc = 0.44
# Epoch 59 / 300: Loss = 0.925 Acc = 0.44
# Epoch 60 / 300: Loss = 0.920 Acc = 0.44
# Epoch 61 / 300: Loss = 0.915 Acc = 0.44
# Epoch 62 / 300: Loss = 0.910 Acc = 0.44
# Epoch 63 / 300: Loss = 0.905 Acc = 0.44
# Epoch 64 / 300: Loss = 0.900 Acc = 0.44
# Epoch 65 / 300: Loss = 0.894 Acc = 0.44
# Epoch 66 / 300: Loss = 0.889 Acc = 0.44
# Epoch 67 / 300: Loss = 0.883 Acc = 0.56
# Epoch 68 / 300: Loss = 0.877 Acc = 0.56
# Epoch 69 / 300: Loss = 0.871 Acc = 0.67
# Epoch 70 / 300: Loss = 0.866 Acc = 0.67
# Epoch 71 / 300: Loss = 0.860 Acc = 0.67
# Epoch 72 / 300: Loss = 0.854 Acc = 0.67
# Epoch 73 / 300: Loss = 0.848 Acc = 0.67
# Epoch 74 / 300: Loss = 0.841 Acc = 0.67
# Epoch 75 / 300: Loss = 0.835 Acc = 0.67
# Epoch 76 / 300: Loss = 0.829 Acc = 0.67
# Epoch 77 / 300: Loss = 0.823 Acc = 0.67
# Epoch 78 / 300: Loss = 0.817 Acc = 0.67
# Epoch 79 / 300: Loss = 0.810 Acc = 0.67
# Epoch 80 / 300: Loss = 0.804 Acc = 0.67
# Epoch 81 / 300: Loss = 0.798 Acc = 0.67
# Epoch 82 / 300: Loss = 0.792 Acc = 0.67
# Epoch 83 / 300: Loss = 0.785 Acc = 0.67
# Epoch 84 / 300: Loss = 0.779 Acc = 0.67
# Epoch 85 / 300: Loss = 0.773 Acc = 0.67
# Epoch 86 / 300: Loss = 0.767 Acc = 0.67
# Epoch 87 / 300: Loss = 0.761 Acc = 0.67
# Epoch 88 / 300: Loss = 0.755 Acc = 0.67
# Epoch 89 / 300: Loss = 0.748 Acc = 0.67
# Epoch 90 / 300: Loss = 0.742 Acc = 0.67
# Epoch 91 / 300: Loss = 0.736 Acc = 0.67
# Epoch 92 / 300: Loss = 0.731 Acc = 0.67
# Epoch 93 / 300: Loss = 0.725 Acc = 0.67
# Epoch 94 / 300: Loss = 0.719 Acc = 0.67
# Epoch 95 / 300: Loss = 0.713 Acc = 0.67
# Epoch 96 / 300: Loss = 0.707 Acc = 0.67
# Epoch 97 / 300: Loss = 0.702 Acc = 0.67
# Epoch 98 / 300: Loss = 0.696 Acc = 0.67
# Epoch 99 / 300: Loss = 0.691 Acc = 0.67
# Epoch 100 / 300: Loss = 0.685 Acc = 0.67
# Epoch 101 / 300: Loss = 0.680 Acc = 0.67
# Epoch 102 / 300: Loss = 0.674 Acc = 0.67
# Epoch 103 / 300: Loss = 0.669 Acc = 0.67
# Epoch 104 / 300: Loss = 0.664 Acc = 0.67
# Epoch 105 / 300: Loss = 0.659 Acc = 0.67
# Epoch 106 / 300: Loss = 0.653 Acc = 0.67
# Epoch 107 / 300: Loss = 0.648 Acc = 0.78
# Epoch 108 / 300: Loss = 0.643 Acc = 0.78
# Epoch 109 / 300: Loss = 0.638 Acc = 0.78
# Epoch 110 / 300: Loss = 0.633 Acc = 0.78
# Epoch 111 / 300: Loss = 0.628 Acc = 0.78
# Epoch 112 / 300: Loss = 0.623 Acc = 0.78
# Epoch 113 / 300: Loss = 0.618 Acc = 0.78
# Epoch 114 / 300: Loss = 0.614 Acc = 0.78
# Epoch 115 / 300: Loss = 0.609 Acc = 0.78
# Epoch 116 / 300: Loss = 0.604 Acc = 0.78
# Epoch 117 / 300: Loss = 0.599 Acc = 0.78
# Epoch 118 / 300: Loss = 0.594 Acc = 0.78
# Epoch 119 / 300: Loss = 0.590 Acc = 0.78
# Epoch 120 / 300: Loss = 0.585 Acc = 0.78
# Epoch 121 / 300: Loss = 0.580 Acc = 0.78
# Epoch 122 / 300: Loss = 0.576 Acc = 0.78
# Epoch 123 / 300: Loss = 0.571 Acc = 0.78
# Epoch 124 / 300: Loss = 0.566 Acc = 0.78
# Epoch 125 / 300: Loss = 0.562 Acc = 0.78
# Epoch 126 / 300: Loss = 0.557 Acc = 0.78
# Epoch 127 / 300: Loss = 0.552 Acc = 0.78
# Epoch 128 / 300: Loss = 0.548 Acc = 0.78
# Epoch 129 / 300: Loss = 0.543 Acc = 0.89
# Epoch 130 / 300: Loss = 0.538 Acc = 0.89
# Epoch 131 / 300: Loss = 0.534 Acc = 0.89
# Epoch 132 / 300: Loss = 0.529 Acc = 0.89
# Epoch 133 / 300: Loss = 0.524 Acc = 0.89
# Epoch 134 / 300: Loss = 0.520 Acc = 0.89
# Epoch 135 / 300: Loss = 0.515 Acc = 0.89
# Epoch 136 / 300: Loss = 0.510 Acc = 0.89
# Epoch 137 / 300: Loss = 0.506 Acc = 0.89
# Epoch 138 / 300: Loss = 0.501 Acc = 0.89
# Epoch 139 / 300: Loss = 0.496 Acc = 0.89
# Epoch 140 / 300: Loss = 0.492 Acc = 0.89
# Epoch 141 / 300: Loss = 0.487 Acc = 0.89
# Epoch 142 / 300: Loss = 0.482 Acc = 0.89
# Epoch 143 / 300: Loss = 0.477 Acc = 0.89
# Epoch 144 / 300: Loss = 0.473 Acc = 0.89
# Epoch 145 / 300: Loss = 0.468 Acc = 0.89
# Epoch 146 / 300: Loss = 0.463 Acc = 0.89
# Epoch 147 / 300: Loss = 0.458 Acc = 0.89
# Epoch 148 / 300: Loss = 0.453 Acc = 0.89
# Epoch 149 / 300: Loss = 0.448 Acc = 0.89
# Epoch 150 / 300: Loss = 0.443 Acc = 0.89
# Epoch 151 / 300: Loss = 0.438 Acc = 0.89
# Epoch 152 / 300: Loss = 0.433 Acc = 0.89
# Epoch 153 / 300: Loss = 0.428 Acc = 0.89
# Epoch 154 / 300: Loss = 0.423 Acc = 0.89
# Epoch 155 / 300: Loss = 0.418 Acc = 0.89
# Epoch 156 / 300: Loss = 0.413 Acc = 1.00
# Epoch 157 / 300: Loss = 0.407 Acc = 1.00
# Epoch 158 / 300: Loss = 0.402 Acc = 1.00
# Epoch 159 / 300: Loss = 0.397 Acc = 1.00
# Epoch 160 / 300: Loss = 0.391 Acc = 1.00
# Epoch 161 / 300: Loss = 0.386 Acc = 1.00
# Epoch 162 / 300: Loss = 0.380 Acc = 1.00
# Epoch 163 / 300: Loss = 0.374 Acc = 1.00
# Epoch 164 / 300: Loss = 0.369 Acc = 1.00
# Epoch 165 / 300: Loss = 0.363 Acc = 1.00
# Epoch 166 / 300: Loss = 0.357 Acc = 1.00
# Epoch 167 / 300: Loss = 0.351 Acc = 1.00
# Epoch 168 / 300: Loss = 0.345 Acc = 1.00
# Epoch 169 / 300: Loss = 0.339 Acc = 1.00
# Epoch 170 / 300: Loss = 0.333 Acc = 1.00
# Epoch 171 / 300: Loss = 0.327 Acc = 1.00
# Epoch 172 / 300: Loss = 0.321 Acc = 1.00
# Epoch 173 / 300: Loss = 0.315 Acc = 1.00
# Epoch 174 / 300: Loss = 0.308 Acc = 1.00
# Epoch 175 / 300: Loss = 0.302 Acc = 1.00
# Epoch 176 / 300: Loss = 0.296 Acc = 1.00
# Epoch 177 / 300: Loss = 0.290 Acc = 1.00
# Epoch 178 / 300: Loss = 0.284 Acc = 1.00
# Epoch 179 / 300: Loss = 0.279 Acc = 1.00
# Epoch 180 / 300: Loss = 0.273 Acc = 1.00
# Epoch 181 / 300: Loss = 0.267 Acc = 1.00
# Epoch 182 / 300: Loss = 0.262 Acc = 1.00
# Epoch 183 / 300: Loss = 0.256 Acc = 1.00
# Epoch 184 / 300: Loss = 0.251 Acc = 1.00
# Epoch 185 / 300: Loss = 0.246 Acc = 1.00
# Epoch 186 / 300: Loss = 0.241 Acc = 1.00
# Epoch 187 / 300: Loss = 0.236 Acc = 1.00
# Epoch 188 / 300: Loss = 0.231 Acc = 1.00
# Epoch 189 / 300: Loss = 0.226 Acc = 1.00
# Epoch 190 / 300: Loss = 0.222 Acc = 1.00
# Epoch 191 / 300: Loss = 0.218 Acc = 1.00
# Epoch 192 / 300: Loss = 0.213 Acc = 1.00
# Epoch 193 / 300: Loss = 0.209 Acc = 1.00
# Epoch 194 / 300: Loss = 0.205 Acc = 1.00
# Epoch 195 / 300: Loss = 0.201 Acc = 1.00
# Epoch 196 / 300: Loss = 0.197 Acc = 1.00
# Epoch 197 / 300: Loss = 0.194 Acc = 1.00
# Epoch 198 / 300: Loss = 0.190 Acc = 1.00
# Epoch 199 / 300: Loss = 0.186 Acc = 1.00
# Epoch 200 / 300: Loss = 0.183 Acc = 1.00
# Epoch 201 / 300: Loss = 0.180 Acc = 1.00
# Epoch 202 / 300: Loss = 0.176 Acc = 1.00
# Epoch 203 / 300: Loss = 0.173 Acc = 1.00
# Epoch 204 / 300: Loss = 0.170 Acc = 1.00
# Epoch 205 / 300: Loss = 0.167 Acc = 1.00
# Epoch 206 / 300: Loss = 0.164 Acc = 1.00
# Epoch 207 / 300: Loss = 0.161 Acc = 1.00
# Epoch 208 / 300: Loss = 0.159 Acc = 1.00
# Epoch 209 / 300: Loss = 0.156 Acc = 1.00
# Epoch 210 / 300: Loss = 0.153 Acc = 1.00
# Epoch 211 / 300: Loss = 0.151 Acc = 1.00
# Epoch 212 / 300: Loss = 0.149 Acc = 1.00
# Epoch 213 / 300: Loss = 0.146 Acc = 1.00
# Epoch 214 / 300: Loss = 0.144 Acc = 1.00
# Epoch 215 / 300: Loss = 0.142 Acc = 1.00
# Epoch 216 / 300: Loss = 0.139 Acc = 1.00
# Epoch 217 / 300: Loss = 0.137 Acc = 1.00
# Epoch 218 / 300: Loss = 0.135 Acc = 1.00
# Epoch 219 / 300: Loss = 0.133 Acc = 1.00
# Epoch 220 / 300: Loss = 0.131 Acc = 1.00
# Epoch 221 / 300: Loss = 0.129 Acc = 1.00
# Epoch 222 / 300: Loss = 0.127 Acc = 1.00
# Epoch 223 / 300: Loss = 0.125 Acc = 1.00
# Epoch 224 / 300: Loss = 0.124 Acc = 1.00
# Epoch 225 / 300: Loss = 0.122 Acc = 1.00
# Epoch 226 / 300: Loss = 0.120 Acc = 1.00
# Epoch 227 / 300: Loss = 0.119 Acc = 1.00
# Epoch 228 / 300: Loss = 0.117 Acc = 1.00
# Epoch 229 / 300: Loss = 0.115 Acc = 1.00
# Epoch 230 / 300: Loss = 0.114 Acc = 1.00
# Epoch 231 / 300: Loss = 0.112 Acc = 1.00
# Epoch 232 / 300: Loss = 0.111 Acc = 1.00
# Epoch 233 / 300: Loss = 0.110 Acc = 1.00
# Epoch 234 / 300: Loss = 0.108 Acc = 1.00
# Epoch 235 / 300: Loss = 0.107 Acc = 1.00
# Epoch 236 / 300: Loss = 0.105 Acc = 1.00
# Epoch 237 / 300: Loss = 0.104 Acc = 1.00
# Epoch 238 / 300: Loss = 0.103 Acc = 1.00
# Epoch 239 / 300: Loss = 0.102 Acc = 1.00
# Epoch 240 / 300: Loss = 0.100 Acc = 1.00
# Epoch 241 / 300: Loss = 0.099 Acc = 1.00
# Epoch 242 / 300: Loss = 0.098 Acc = 1.00
# Epoch 243 / 300: Loss = 0.097 Acc = 1.00
# Epoch 244 / 300: Loss = 0.096 Acc = 1.00
# Epoch 245 / 300: Loss = 0.095 Acc = 1.00
# Epoch 246 / 300: Loss = 0.094 Acc = 1.00
# Epoch 247 / 300: Loss = 0.093 Acc = 1.00
# Epoch 248 / 300: Loss = 0.092 Acc = 1.00
# Epoch 249 / 300: Loss = 0.091 Acc = 1.00
# Epoch 250 / 300: Loss = 0.090 Acc = 1.00
# Epoch 251 / 300: Loss = 0.089 Acc = 1.00
# Epoch 252 / 300: Loss = 0.088 Acc = 1.00
# Epoch 253 / 300: Loss = 0.087 Acc = 1.00
# Epoch 254 / 300: Loss = 0.086 Acc = 1.00
# Epoch 255 / 300: Loss = 0.085 Acc = 1.00
# Epoch 256 / 300: Loss = 0.084 Acc = 1.00
# Epoch 257 / 300: Loss = 0.083 Acc = 1.00
# Epoch 258 / 300: Loss = 0.082 Acc = 1.00
# Epoch 259 / 300: Loss = 0.082 Acc = 1.00
# Epoch 260 / 300: Loss = 0.081 Acc = 1.00
# Epoch 261 / 300: Loss = 0.080 Acc = 1.00
# Epoch 262 / 300: Loss = 0.079 Acc = 1.00
# Epoch 263 / 300: Loss = 0.079 Acc = 1.00
# Epoch 264 / 300: Loss = 0.078 Acc = 1.00
# Epoch 265 / 300: Loss = 0.077 Acc = 1.00
# Epoch 266 / 300: Loss = 0.076 Acc = 1.00
# Epoch 267 / 300: Loss = 0.076 Acc = 1.00
# Epoch 268 / 300: Loss = 0.075 Acc = 1.00
# Epoch 269 / 300: Loss = 0.074 Acc = 1.00
# Epoch 270 / 300: Loss = 0.074 Acc = 1.00
# Epoch 271 / 300: Loss = 0.073 Acc = 1.00
# Epoch 272 / 300: Loss = 0.072 Acc = 1.00
# Epoch 273 / 300: Loss = 0.072 Acc = 1.00
# Epoch 274 / 300: Loss = 0.071 Acc = 1.00
# Epoch 275 / 300: Loss = 0.070 Acc = 1.00
# Epoch 276 / 300: Loss = 0.070 Acc = 1.00
# Epoch 277 / 300: Loss = 0.069 Acc = 1.00
# Epoch 278 / 300: Loss = 0.069 Acc = 1.00
# Epoch 279 / 300: Loss = 0.068 Acc = 1.00
# Epoch 280 / 300: Loss = 0.068 Acc = 1.00
# Epoch 281 / 300: Loss = 0.067 Acc = 1.00
# Epoch 282 / 300: Loss = 0.066 Acc = 1.00
# Epoch 283 / 300: Loss = 0.066 Acc = 1.00
# Epoch 284 / 300: Loss = 0.065 Acc = 1.00
# Epoch 285 / 300: Loss = 0.065 Acc = 1.00
# Epoch 286 / 300: Loss = 0.064 Acc = 1.00
# Epoch 287 / 300: Loss = 0.064 Acc = 1.00
# Epoch 288 / 300: Loss = 0.063 Acc = 1.00
# Epoch 289 / 300: Loss = 0.063 Acc = 1.00
# Epoch 290 / 300: Loss = 0.062 Acc = 1.00
# Epoch 291 / 300: Loss = 0.062 Acc = 1.00
# Epoch 292 / 300: Loss = 0.061 Acc = 1.00
# Epoch 293 / 300: Loss = 0.061 Acc = 1.00
# Epoch 294 / 300: Loss = 0.061 Acc = 1.00
# Epoch 295 / 300: Loss = 0.060 Acc = 1.00
# Epoch 296 / 300: Loss = 0.060 Acc = 1.00
# Epoch 297 / 300: Loss = 0.059 Acc = 1.00
# Epoch 298 / 300: Loss = 0.059 Acc = 1.00
# Epoch 299 / 300: Loss = 0.058 Acc = 1.00
# Epoch 300 / 300: Loss = 0.058 Acc = 1.00

# %%
print_result(model_quantum)
# Out:
# Sentence:  ['The', 'dog', 'ate', 'the', 'apple']
# Labels:    ['DET', 'NN', 'V', 'DET', 'NN']
# Predicted: ['DET', 'NN', 'V', 'DET', 'NN']

# %% [markdown]
# ### Plot the training history

# %%
from matplotlib import pyplot as plt

def plot_history(history_classical, history_quantum):
    loss_c = history_classical['loss']
    acc_c = history_classical['acc']
    loss_q = history_quantum['loss']
    acc_q = history_quantum['acc']
    n_epochs = max([len(loss_c), len(loss_q)])
    x_epochs = [i for i in range(n_epochs)]
    
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.plot(loss_c, label="Classical LSTM loss", color='orange', linestyle='dashed')
    ax1.plot(loss_q, label="Quantum LSTM loss", color='red', linestyle='solid')

    ax2 = ax1.twinx()
    ax2.set_ylabel("Accuracy")
    ax2.plot(acc_c, label="Classical LSTM accuracy", color='steelblue', linestyle='dashed')
    ax2.plot(acc_q, label="Quantum LSTM accuracy", color='blue', linestyle='solid')

    plt.title("Part-of-Speech Tagger Training__torch")
    plt.ylim(0., 1.1)
    #plt.legend(loc="upper right")
    fig.legend(loc="upper right", bbox_to_anchor=(1,0.8), bbox_transform=ax1.transAxes)

    plt.savefig("pos_training__torch.pdf")
    plt.savefig("pos_training__torch.png")
    
    plt.show()

# %%
# %matplotlib inline
plot_history(history_classical, history_quantum)

# %% [markdown]
# The loss function decreases as a function of the training epoch, and after 300 epochs both networks are able to tag correctly the first sentence. Due to the complexity of the simulation of the quantum circuit, it took approximatively 15 minutes to finish the training, to be compared to a mere 8 seconds for the classical case.

# %% [markdown]
# ## Refrences

# %% [markdown]
# [1] Riccardo Di Sipio, Jia-Hong Huang, Samuel Yen-
# Chi Chen, Stefano Mangini, and Marcel Worring.
# The dawn of quantum natural language processing.
# In ICASSP 2022-2022 IEEE International Confer-
# ence on Acoustics, Speech and Signal Processing
# (ICASSP), pages 8612–8616. IEEE, 2022.
